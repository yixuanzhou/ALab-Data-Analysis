# %%
import numpy as np
import scipy
import pandas as pd
import matplotlib.pyplot as plt
from process import readlvm

# %% [markdown]
# ## paramaters

# %%
lambda0=1572.42
slope=396.5
modulation_coefficient=0.052

# %% [markdown]
# ## read lvm data

# %%
base = readlvm("Q/Q-1553.350-00.lvm");
time = base[:,0]
taper = base[:,1]

# %%
q1 = readlvm("Q/Q-1553.350-01.lvm")
q1 = q1.ravel()
q1 = q1 / taper - 1
#plt.plot(q1)
valley =  q1.min()
valley_index = np.argmin(q1)
q1_valley = q1[valley_index-5000:valley_index+5000]
plt.plot(q1_valley)

# %%
plt.plot(q1_valley)

# %%
from scipy.signal import find_peaks, peak_widths
q1_valley = q1_valley * -1
peaks, peak_info = find_peaks(q1_valley, height=-valley)
results_half = peak_widths(q1_valley, peaks, rel_height=0.5)
plt.plot(q1_valley)
plt.plot(peaks, q1_valley[peaks], "x")
plt.plot(np.zeros_like(q1_valley), "--", color="gray")
plt.show()
print(results_half[0])
print(peak_info)
# Out:
# [403.55060061]
# {'peak_heights': array([0.13506554])}

# %%
from lmfit.models import LorentzianModel
mod = LorentzianModel()
x = np.asarray(list(range(0,10000)))
pars = mod.guess(q1_valley, x=x)
out = mod.fit(q1_valley, pars, x=x)

# %%
print(out.fit_report())
plt.plot(x, q1_valley, 'b')
plt.plot(x, out.init_fit, 'k--')
plt.plot(x, out.best_fit, 'r-')
plt.show()
# Out:
# [[Model]]
#     Model(lorentzian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 71
#     # data points      = 10000
#     # variables        = 3
#     chi-square         = 3.17418796
#     reduced chi-square = 3.1751e-04
#     Akaike info crit   = -80546.8853
#     Bayesian info crit = -80525.2543
# [[Variables]]
#     sigma:      451.308414 +/- 6.43193067 (1.43%) (init = 4931)
#     center:     4942.47752 +/- 4.54183462 (0.09%) (init = 4927.339)
#     amplitude:  133.335921 +/- 1.34352527 (1.01%) (init = 3625.379)
#     fwhm:       902.616829 +/- 12.8638613 (1.43%) == '2.0000000*sigma'
#     height:     0.09404244 +/- 9.4670e-04 (1.01%) == '0.3183099*amplitude/max(1.e-15, sigma)'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(sigma, amplitude) =  0.708

# %%
res = out.fit_report()
info = res.split("\n")

height = info[-4]
height = height.replace(" ", "")
h_res = height.split(":")[1]
h_res = h_res[:h_res.find("+")]

fwhm = info[-5]
fwhm = fwhm.replace(" ", "")
w_res = fwhm.split(":")[1]
w_res = w_res[:w_res.find("+")]

center = info[-7]
center = center.replace(" ", "")
c_res = center.split(":")[1]
c_res = c_res[:c_res.find("+")]
print(h_res, w_res, c_res)
# Out:
# 0.09404244 902.616829 4942.47752

# %%
l = lambda0 + float(c_res) / taper.size * (time[-1]-time[0]) * slope * modulation_coefficient
d_lambda = float(w_res) / taper.size *  (time[-1]-time[0]) * slope * modulation_coefficient
Q = l / d_lambda
Q
# Out:
# 10561587.048998931

# %%
plt.plot(h_res, Q, marker='o', markersize=5, color="red")

# %%
from calculateQ import baseQ
Qs, couplings = baseQ("Q/Q-1553.350-00.lvm")
plt.scatter(couplings, Qs, c="red")
plt.show()

# %%
x = np.asarray(couplings[:-1], dtype='float')
print(x)
Y = np.asarray(Qs[:-1], dtype='float')
A = np.vstack([x, np.ones(len(x))]).T
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
plt.plot(x, Y, 'o', label='Original data', markersize=10)
plt.plot(x, m*x + c, 'r', label='Fitted line')
plt.legend()
# Out:
# [9.404244 8.826208 7.285069 5.688095 4.992477 9.772658 5.440238 5.132084
#  5.773267]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-1fa0d91fb34a> in <module>()
#       1 from outlierRemoval import removeOutliers
# ----> 2 res = removeOutliers(Y, 0.5)
#
# ~/Documents/ALab-Data-Analysis/outlierRemoval.py in removeOutliers(x, outlierConstant)
#       1 import numpy as np
# ----> 2
#       3 def removeOutliers(x, outlierConstant):
#       4     upper_quartile = np.percentile(x, 75)
#       5     lower_quartile = np.percentile(x, 25)
#
# NameError: name 'np' is not defined

# %%
from outlierRemoval import removeOutliers
res = removeOutliers(Y, 0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-1fa0d91fb34a> in <module>()
#       1 from outlierRemoval import removeOutliers
# ----> 2 res = removeOutliers(Y, 0.5)
#
# ~/Documents/ALab-Data-Analysis/outlierRemoval.py in removeOutliers(x, outlierConstant)
#       1 import numpy as np
# ----> 2
#       3 def removeOutliers(x, outlierConstant):
#       4     upper_quartile = np.percentile(x, 75)
#       5     lower_quartile = np.percentile(x, 25)
#
# NameError: name 'np' is not defined
